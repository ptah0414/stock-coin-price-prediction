# %%
# !pip install pytrends
# Out:
# Collecting pytrends
#   Downloading pytrends-4.8.0.tar.gz (19 kB)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.7/dist-packages (from pytrends) (2.23.0)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.7/dist-packages (from pytrends) (1.3.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pytrends) (4.2.6)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->pytrends) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->pytrends) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25->pytrends) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0->pytrends) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0->pytrends) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0->pytrends) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0->pytrends) (2.10)
# Building wheels for collected packages: pytrends
#   Building wheel for pytrends (setup.py) ... done
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16126 sha256=37f21cfc0440172ef4110f6fa7c18e6fa85cf93954a836d74bd6f00d0707051a
#   Stored in directory: /root/.cache/pip/wheels/07/6f/5c/8174f98dec1bfbc7d5da4092854afcbcff4b26c3d9b66b5183
# Successfully built pytrends
# Installing collected packages: pytrends
# Successfully installed pytrends-4.8.0

# %%
import pytrends
from datetime import datetime
import pandas as pd
from pytrends.request import TrendReq

# %%
keyword = ["bitcoin"]

# %%
startdate = "2017-09-25"

# %%
enddate = str(datetime.today()).split(" ")[0]
enddate
# Out:
# '2022-05-18'

# %%
timerange = startdate + " " + enddate

# %%
result = pd.DataFrame()

# %%
pytrends = TrendReq()

# %%
pytrends.build_payload(kw_list = keyword, timeframe = timerange)
data = pytrends.interest_over_time()
data
# Out:
#             bitcoin  isPartial
# date
# 2017-10-01       12      False
# 2017-10-08       18      False
# 2017-10-15       19      False
# 2017-10-22       20      False
# 2017-10-29       26      False
# ...             ...        ...
# 2022-04-17       17      False
# 2022-04-24       18      False
# 2022-05-01       19      False
# 2022-05-08       41      False
# 2022-05-15       26       True
#
# [242 rows x 2 columns]

# %%
import matplotlib

# %%
data.plot()

# %%
data.tail()
# Out:
#             bitcoin  isPartial
# date
# 2022-04-17       17      False
# 2022-04-24       18      False
# 2022-05-01       19      False
# 2022-05-08       41      False
# 2022-05-15       26       True

# %%
data = data[["bitcoin"]]
data
# Out:
#             bitcoin
# date
# 2017-10-01       12
# 2017-10-08       18
# 2017-10-15       19
# 2017-10-22       20
# 2017-10-29       26
# ...             ...
# 2022-04-17       17
# 2022-04-24       18
# 2022-05-01       19
# 2022-05-08       41
# 2022-05-15       26
#
# [242 rows x 1 columns]

# %%
data = data.reset_index()

# %%
data = data.rename(columns={"date": "Date", "bitcoin": "trends"})
data
# Out:
#           Date  trends
# 0   2017-10-01      12
# 1   2017-10-08      18
# 2   2017-10-15      19
# 3   2017-10-22      20
# 4   2017-10-29      26
# ..         ...     ...
# 237 2022-04-17      17
# 238 2022-04-24      18
# 239 2022-05-01      19
# 240 2022-05-08      41
# 241 2022-05-15      26
#
# [242 rows x 2 columns]

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.70-py2.py3-none-any.whl (26 kB)
# Collecting requests>=2.26
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.5 MB/s
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 46.1 MB/s
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Installing collected packages: requests, lxml, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed lxml-4.8.0 requests-2.27.1 yfinance-0.1.70

# %%
import yfinance as yf
from datetime import datetime
import pandas_datareader as pdr
import pandas as pd

# %%
final = datetime.today()

# %%
vix = yf.download('^VIX', interval='1d', start="2017-09-25", end=final)['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
vix = pd.DataFrame(vix)
vix
# Out:
#                 Close
# Date
# 2017-09-25  10.210000
# 2017-09-26  10.170000
# 2017-09-27   9.870000
# 2017-09-28   9.550000
# 2017-09-29   9.510000
# ...               ...
# 2022-05-12  31.770000
# 2022-05-13  28.870001
# 2022-05-16  27.469999
# 2022-05-17  26.100000
# 2022-05-18  26.570000
#
# [1171 rows x 1 columns]

# %%
vix_close = vix.rename(columns={"Close": "vix_close"})
vix_close
# Out:
#             vix_close
# Date
# 2017-09-25  10.210000
# 2017-09-26  10.170000
# 2017-09-27   9.870000
# 2017-09-28   9.550000
# 2017-09-29   9.510000
# ...               ...
# 2022-05-12  31.770000
# 2022-05-13  28.870001
# 2022-05-16  27.469999
# 2022-05-17  26.100000
# 2022-05-18  26.570000
#
# [1171 rows x 1 columns]

# %%
# !pip install pyupbit
# Out:
# Collecting pyupbit
#   Downloading pyupbit-0.2.30-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pyupbit) (2.27.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pyupbit) (1.3.5)
# Collecting pyjwt>=2.0.0
#   Downloading PyJWT-2.4.0-py3-none-any.whl (18 kB)
# Collecting websockets
#   Downloading websockets-10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (112 kB)
#      |████████████████████████████████| 112 kB 32.8 MB/s
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyupbit) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyupbit) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyupbit) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pyupbit) (1.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests->pyupbit) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pyupbit) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pyupbit) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pyupbit) (2021.10.8)
# Installing collected packages: websockets, pyjwt, pyupbit
# Successfully installed pyjwt-2.4.0 pyupbit-0.2.30 websockets-10.3

# %%
import time
import pyupbit
import datetime

# %%
access = "key"
secret = "key"

# %%
# 로그인
upbit = pyupbit.Upbit(access, secret)

# %% [markdown]
# # 2017-09-25 ~ 현재 -> 약 1690개

# %%
ticker = "KRW-BTC"
df = pyupbit.get_ohlcv(ticker, interval="day", count=3650)

# %%
df_org = df.copy()

# %%
df = df_org

# %%
df.head()
# Out:
#                                 open       high        low      close  \
# 2017-09-25 09:00:00+00:00  4201000.0  4333000.0  4175000.0  4322000.0
# 2017-09-26 09:00:00+00:00  4317000.0  4418000.0  4311000.0  4321000.0
# 2017-09-27 09:00:00+00:00  4322000.0  4677000.0  4318000.0  4657000.0
# 2017-09-28 09:00:00+00:00  4657000.0  4772000.0  4519000.0  4586000.0
# 2017-09-29 09:00:00+00:00  4586000.0  4709000.0  4476000.0  4657000.0
#
#                                volume         value
# 2017-09-25 09:00:00+00:00  132.484755  5.602146e+08
# 2017-09-26 09:00:00+00:00   22.788340  9.950724e+07
# 2017-09-27 09:00:00+00:00   32.269662  1.448276e+08
# 2017-09-28 09:00:00+00:00   80.588243  3.721860e+08
# 2017-09-29 09:00:00+00:00   59.352373  2.724558e+08

# %%
df.reset_index(inplace=True)
df
# Out:
#                          index        open        high         low  \
# 0    2017-09-25 09:00:00+00:00   4201000.0   4333000.0   4175000.0
# 1    2017-09-26 09:00:00+00:00   4317000.0   4418000.0   4311000.0
# 2    2017-09-27 09:00:00+00:00   4322000.0   4677000.0   4318000.0
# 3    2017-09-28 09:00:00+00:00   4657000.0   4772000.0   4519000.0
# 4    2017-09-29 09:00:00+00:00   4586000.0   4709000.0   4476000.0
# ...                        ...         ...         ...         ...
# 1692 2022-05-14 09:00:00+00:00  39270000.0  40243000.0  38400000.0
# 1693 2022-05-15 09:00:00+00:00  39967000.0  41000000.0  39270000.0
# 1694 2022-05-16 09:00:00+00:00  40902000.0  40940000.0  38620000.0
# 1695 2022-05-17 09:00:00+00:00  39260000.0  39900000.0  38416000.0
# 1696 2022-05-18 09:00:00+00:00  39260000.0  39464000.0  38440000.0
#
#            close       volume         value
# 0      4322000.0   132.484755  5.602146e+08
# 1      4321000.0    22.788340  9.950724e+07
# 2      4657000.0    32.269662  1.448276e+08
# 3      4586000.0    80.588243  3.721860e+08
# 4      4657000.0    59.352373  2.724558e+08
# ...          ...          ...           ...
# 1692  39967000.0  5512.195620  2.170088e+11
# 1693  40906000.0  4277.655034  1.706726e+11
# 1694  39256000.0  5678.833853  2.243704e+11
# 1695  39259000.0  5356.753182  2.105359e+11
# 1696  38550000.0  2196.484708  8.528940e+10
#
# [1697 rows x 7 columns]

# %%
df = df.rename(columns={"index": "Date"})
df
# Out:
#                           Date        open        high         low  \
# 0    2017-09-25 09:00:00+00:00   4201000.0   4333000.0   4175000.0
# 1    2017-09-26 09:00:00+00:00   4317000.0   4418000.0   4311000.0
# 2    2017-09-27 09:00:00+00:00   4322000.0   4677000.0   4318000.0
# 3    2017-09-28 09:00:00+00:00   4657000.0   4772000.0   4519000.0
# 4    2017-09-29 09:00:00+00:00   4586000.0   4709000.0   4476000.0
# ...                        ...         ...         ...         ...
# 1692 2022-05-14 09:00:00+00:00  39270000.0  40243000.0  38400000.0
# 1693 2022-05-15 09:00:00+00:00  39967000.0  41000000.0  39270000.0
# 1694 2022-05-16 09:00:00+00:00  40902000.0  40940000.0  38620000.0
# 1695 2022-05-17 09:00:00+00:00  39260000.0  39900000.0  38416000.0
# 1696 2022-05-18 09:00:00+00:00  39260000.0  39464000.0  38440000.0
#
#            close       volume         value
# 0      4322000.0   132.484755  5.602146e+08
# 1      4321000.0    22.788340  9.950724e+07
# 2      4657000.0    32.269662  1.448276e+08
# 3      4586000.0    80.588243  3.721860e+08
# 4      4657000.0    59.352373  2.724558e+08
# ...          ...          ...           ...
# 1692  39967000.0  5512.195620  2.170088e+11
# 1693  40906000.0  4277.655034  1.706726e+11
# 1694  39256000.0  5678.833853  2.243704e+11
# 1695  39259000.0  5356.753182  2.105359e+11
# 1696  38550000.0  2196.484708  8.528940e+10
#
# [1697 rows x 7 columns]

# %%
df["Date"] = pd.to_datetime(df["Date"].dt.date)
df
# Out:
#            Date        open        high         low       close       volume  \
# 0    2017-09-25   4201000.0   4333000.0   4175000.0   4322000.0   132.484755
# 1    2017-09-26   4317000.0   4418000.0   4311000.0   4321000.0    22.788340
# 2    2017-09-27   4322000.0   4677000.0   4318000.0   4657000.0    32.269662
# 3    2017-09-28   4657000.0   4772000.0   4519000.0   4586000.0    80.588243
# 4    2017-09-29   4586000.0   4709000.0   4476000.0   4657000.0    59.352373
# ...         ...         ...         ...         ...         ...          ...
# 1692 2022-05-14  39270000.0  40243000.0  38400000.0  39967000.0  5512.195620
# 1693 2022-05-15  39967000.0  41000000.0  39270000.0  40906000.0  4277.655034
# 1694 2022-05-16  40902000.0  40940000.0  38620000.0  39256000.0  5678.833853
# 1695 2022-05-17  39260000.0  39900000.0  38416000.0  39259000.0  5356.753182
# 1696 2022-05-18  39260000.0  39464000.0  38440000.0  38550000.0  2196.484708
#
#              value
# 0     5.602146e+08
# 1     9.950724e+07
# 2     1.448276e+08
# 3     3.721860e+08
# 4     2.724558e+08
# ...            ...
# 1692  2.170088e+11
# 1693  1.706726e+11
# 1694  2.243704e+11
# 1695  2.105359e+11
# 1696  8.528940e+10
#
# [1697 rows x 7 columns]

# %%
vix_close[["vix_close"]]
# Out:
#             vix_close
# Date
# 2017-09-25  10.210000
# 2017-09-26  10.170000
# 2017-09-27   9.870000
# 2017-09-28   9.550000
# 2017-09-29   9.510000
# ...               ...
# 2022-05-12  31.770000
# 2022-05-13  28.870001
# 2022-05-16  27.469999
# 2022-05-17  26.100000
# 2022-05-18  26.570000
#
# [1171 rows x 1 columns]

# %%
df = pd.merge(df, vix_close, on="Date", how="left")
df.head(20)
# Out:
#          Date       open       high        low      close      volume  \
# 0  2017-09-25  4201000.0  4333000.0  4175000.0  4322000.0  132.484755
# 1  2017-09-26  4317000.0  4418000.0  4311000.0  4321000.0   22.788340
# 2  2017-09-27  4322000.0  4677000.0  4318000.0  4657000.0   32.269662
# 3  2017-09-28  4657000.0  4772000.0  4519000.0  4586000.0   80.588243
# 4  2017-09-29  4586000.0  4709000.0  4476000.0  4657000.0   59.352373
# 5  2017-09-30  4657000.0  4896000.0  4651000.0  4895000.0   19.998483
# 6  2017-10-01  4889000.0  4978000.0  4682000.0  4962000.0   27.323332
# 7  2017-10-02  4962000.0  5095000.0  4956000.0  5025000.0   31.728004
# 8  2017-10-03  5021000.0  5079000.0  4811000.0  4964000.0   11.899307
# 9  2017-10-04  4987000.0  5002000.0  4837000.0  4895000.0    7.038744
# 10 2017-10-05  4894000.0  4993000.0  4811000.0  4926000.0    5.363652
# 11 2017-10-06  4927000.0  5034000.0  4885000.0  5027000.0   25.163820
# 12 2017-10-07  4983000.0  5070000.0  4935000.0  5047000.0    4.343932
# 13 2017-10-08  5044000.0  5263000.0  4993000.0  5217000.0  145.917860
# 14 2017-10-09  5222000.0  5761000.0  5188000.0  5477000.0    8.070434
# 15 2017-10-10  5469000.0  5665000.0  5459000.0  5486000.0   11.693694
# 16 2017-10-11  5533000.0  5605000.0  5451000.0  5557000.0    4.212650
# 17 2017-10-12  5569000.0  6377000.0  5515000.0  6332000.0   20.918287
# 18 2017-10-13  6346000.0  6950000.0  6149000.0  6438000.0   26.826084
# 19 2017-10-14  6427000.0  6664000.0  6322000.0  6664000.0    3.352825
#
#            value  vix_close
# 0   5.602146e+08      10.21
# 1   9.950724e+07      10.17
# 2   1.448276e+08       9.87
# 3   3.721860e+08       9.55
# 4   2.724558e+08       9.51
# 5   9.561476e+07        NaN
# 6   1.331325e+08        NaN
# 7   1.599315e+08       9.45
# 8   5.890130e+07       9.51
# 9   3.458813e+07       9.63
# 10  2.637132e+07       9.19
# 11  1.239351e+08       9.65
# 12  2.166749e+07        NaN
# 13  7.382940e+08        NaN
# 14  4.327059e+07      10.33
# 15  6.482276e+07      10.08
# 16  2.332489e+07       9.85
# 17  1.189924e+08       9.91
# 18  1.752832e+08       9.61
# 19  2.171336e+07        NaN

# %%
df = df.fillna(method = "ffill")
df.head(20)
# Out:
#          Date       open       high        low      close      volume  \
# 0  2017-09-25  4201000.0  4333000.0  4175000.0  4322000.0  132.484755
# 1  2017-09-26  4317000.0  4418000.0  4311000.0  4321000.0   22.788340
# 2  2017-09-27  4322000.0  4677000.0  4318000.0  4657000.0   32.269662
# 3  2017-09-28  4657000.0  4772000.0  4519000.0  4586000.0   80.588243
# 4  2017-09-29  4586000.0  4709000.0  4476000.0  4657000.0   59.352373
# 5  2017-09-30  4657000.0  4896000.0  4651000.0  4895000.0   19.998483
# 6  2017-10-01  4889000.0  4978000.0  4682000.0  4962000.0   27.323332
# 7  2017-10-02  4962000.0  5095000.0  4956000.0  5025000.0   31.728004
# 8  2017-10-03  5021000.0  5079000.0  4811000.0  4964000.0   11.899307
# 9  2017-10-04  4987000.0  5002000.0  4837000.0  4895000.0    7.038744
# 10 2017-10-05  4894000.0  4993000.0  4811000.0  4926000.0    5.363652
# 11 2017-10-06  4927000.0  5034000.0  4885000.0  5027000.0   25.163820
# 12 2017-10-07  4983000.0  5070000.0  4935000.0  5047000.0    4.343932
# 13 2017-10-08  5044000.0  5263000.0  4993000.0  5217000.0  145.917860
# 14 2017-10-09  5222000.0  5761000.0  5188000.0  5477000.0    8.070434
# 15 2017-10-10  5469000.0  5665000.0  5459000.0  5486000.0   11.693694
# 16 2017-10-11  5533000.0  5605000.0  5451000.0  5557000.0    4.212650
# 17 2017-10-12  5569000.0  6377000.0  5515000.0  6332000.0   20.918287
# 18 2017-10-13  6346000.0  6950000.0  6149000.0  6438000.0   26.826084
# 19 2017-10-14  6427000.0  6664000.0  6322000.0  6664000.0    3.352825
#
#            value  vix_close
# 0   5.602146e+08      10.21
# 1   9.950724e+07      10.17
# 2   1.448276e+08       9.87
# 3   3.721860e+08       9.55
# 4   2.724558e+08       9.51
# 5   9.561476e+07       9.51
# 6   1.331325e+08       9.51
# 7   1.599315e+08       9.45
# 8   5.890130e+07       9.51
# 9   3.458813e+07       9.63
# 10  2.637132e+07       9.19
# 11  1.239351e+08       9.65
# 12  2.166749e+07       9.65
# 13  7.382940e+08       9.65
# 14  4.327059e+07      10.33
# 15  6.482276e+07      10.08
# 16  2.332489e+07       9.85
# 17  1.189924e+08       9.91
# 18  1.752832e+08       9.61
# 19  2.171336e+07       9.61

# %%
df_trends = data
df_trends
# Out:
#           Date  trends
# 0   2017-10-01      12
# 1   2017-10-08      18
# 2   2017-10-15      19
# 3   2017-10-22      20
# 4   2017-10-29      26
# ..         ...     ...
# 237 2022-04-17      17
# 238 2022-04-24      18
# 239 2022-05-01      19
# 240 2022-05-08      41
# 241 2022-05-15      26
#
# [242 rows x 2 columns]

# %%
df = pd.merge(df, df_trends, how="outer", on="Date")
df
# Out:
#            Date        open        high         low       close       volume  \
# 0    2017-09-25   4201000.0   4333000.0   4175000.0   4322000.0   132.484755
# 1    2017-09-26   4317000.0   4418000.0   4311000.0   4321000.0    22.788340
# 2    2017-09-27   4322000.0   4677000.0   4318000.0   4657000.0    32.269662
# 3    2017-09-28   4657000.0   4772000.0   4519000.0   4586000.0    80.588243
# 4    2017-09-29   4586000.0   4709000.0   4476000.0   4657000.0    59.352373
# ...         ...         ...         ...         ...         ...          ...
# 1692 2022-05-14  39270000.0  40243000.0  38400000.0  39967000.0  5512.195620
# 1693 2022-05-15  39967000.0  41000000.0  39270000.0  40906000.0  4277.655034
# 1694 2022-05-16  40902000.0  40940000.0  38620000.0  39256000.0  5678.833853
# 1695 2022-05-17  39260000.0  39900000.0  38416000.0  39259000.0  5356.753182
# 1696 2022-05-18  39260000.0  39464000.0  38440000.0  38550000.0  2196.484708
#
#              value  vix_close  trends
# 0     5.602146e+08  10.210000     NaN
# 1     9.950724e+07  10.170000     NaN
# 2     1.448276e+08   9.870000     NaN
# 3     3.721860e+08   9.550000     NaN
# 4     2.724558e+08   9.510000     NaN
# ...            ...        ...     ...
# 1692  2.170088e+11  28.870001     NaN
# 1693  1.706726e+11  28.870001    26.0
# 1694  2.243704e+11  27.469999     NaN
# 1695  2.105359e+11  26.100000     NaN
# 1696  8.528940e+10  26.570000     NaN
#
# [1697 rows x 9 columns]

# %%
df = df.fillna(method = "ffill")
df
# Out:
#            Date        open        high         low       close       volume  \
# 0    2017-09-25   4201000.0   4333000.0   4175000.0   4322000.0   132.484755
# 1    2017-09-26   4317000.0   4418000.0   4311000.0   4321000.0    22.788340
# 2    2017-09-27   4322000.0   4677000.0   4318000.0   4657000.0    32.269662
# 3    2017-09-28   4657000.0   4772000.0   4519000.0   4586000.0    80.588243
# 4    2017-09-29   4586000.0   4709000.0   4476000.0   4657000.0    59.352373
# ...         ...         ...         ...         ...         ...          ...
# 1692 2022-05-14  39270000.0  40243000.0  38400000.0  39967000.0  5512.195620
# 1693 2022-05-15  39967000.0  41000000.0  39270000.0  40906000.0  4277.655034
# 1694 2022-05-16  40902000.0  40940000.0  38620000.0  39256000.0  5678.833853
# 1695 2022-05-17  39260000.0  39900000.0  38416000.0  39259000.0  5356.753182
# 1696 2022-05-18  39260000.0  39464000.0  38440000.0  38550000.0  2196.484708
#
#              value  vix_close  trends
# 0     5.602146e+08  10.210000     NaN
# 1     9.950724e+07  10.170000     NaN
# 2     1.448276e+08   9.870000     NaN
# 3     3.721860e+08   9.550000     NaN
# 4     2.724558e+08   9.510000     NaN
# ...            ...        ...     ...
# 1692  2.170088e+11  28.870001    41.0
# 1693  1.706726e+11  28.870001    26.0
# 1694  2.243704e+11  27.469999    26.0
# 1695  2.105359e+11  26.100000    26.0
# 1696  8.528940e+10  26.570000    26.0
#
# [1697 rows x 9 columns]

# %%
df = df.fillna(method = "bfill")
df
# Out:
#            Date        open        high         low       close       volume  \
# 0    2017-09-25   4201000.0   4333000.0   4175000.0   4322000.0   132.484755
# 1    2017-09-26   4317000.0   4418000.0   4311000.0   4321000.0    22.788340
# 2    2017-09-27   4322000.0   4677000.0   4318000.0   4657000.0    32.269662
# 3    2017-09-28   4657000.0   4772000.0   4519000.0   4586000.0    80.588243
# 4    2017-09-29   4586000.0   4709000.0   4476000.0   4657000.0    59.352373
# ...         ...         ...         ...         ...         ...          ...
# 1692 2022-05-14  39270000.0  40243000.0  38400000.0  39967000.0  5512.195620
# 1693 2022-05-15  39967000.0  41000000.0  39270000.0  40906000.0  4277.655034
# 1694 2022-05-16  40902000.0  40940000.0  38620000.0  39256000.0  5678.833853
# 1695 2022-05-17  39260000.0  39900000.0  38416000.0  39259000.0  5356.753182
# 1696 2022-05-18  39260000.0  39464000.0  38440000.0  38550000.0  2196.484708
#
#              value  vix_close  trends
# 0     5.602146e+08  10.210000    12.0
# 1     9.950724e+07  10.170000    12.0
# 2     1.448276e+08   9.870000    12.0
# 3     3.721860e+08   9.550000    12.0
# 4     2.724558e+08   9.510000    12.0
# ...            ...        ...     ...
# 1692  2.170088e+11  28.870001    41.0
# 1693  1.706726e+11  28.870001    26.0
# 1694  2.243704e+11  27.469999    26.0
# 1695  2.105359e+11  26.100000    26.0
# 1696  8.528940e+10  26.570000    26.0
#
# [1697 rows x 9 columns]

# %% [markdown]
# # non-stationary(price) -> stationary(price_diff)

# %%
df["close_diff"] = df["close"] - df["close"].shift(1)

# %%
df.head()
# Out:
#         Date       open       high        low      close      volume  \
# 0 2017-09-25  4201000.0  4333000.0  4175000.0  4322000.0  132.484755
# 1 2017-09-26  4317000.0  4418000.0  4311000.0  4321000.0   22.788340
# 2 2017-09-27  4322000.0  4677000.0  4318000.0  4657000.0   32.269662
# 3 2017-09-28  4657000.0  4772000.0  4519000.0  4586000.0   80.588243
# 4 2017-09-29  4586000.0  4709000.0  4476000.0  4657000.0   59.352373
#
#           value  vix_close  trends  close_diff
# 0  5.602146e+08      10.21    12.0         NaN
# 1  9.950724e+07      10.17    12.0     -1000.0
# 2  1.448276e+08       9.87    12.0    336000.0
# 3  3.721860e+08       9.55    12.0    -71000.0
# 4  2.724558e+08       9.51    12.0     71000.0

# %%
df2 = df[["close_diff", "volume", "vix_close", "trends", "close"]]
df2.head()
# Out:
#    close_diff      volume  vix_close  trends      close
# 0         NaN  132.484755      10.21    12.0  4322000.0
# 1     -1000.0   22.788340      10.17    12.0  4321000.0
# 2    336000.0   32.269662       9.87    12.0  4657000.0
# 3    -71000.0   80.588243       9.55    12.0  4586000.0
# 4     71000.0   59.352373       9.51    12.0  4657000.0

# %% [markdown]
# # Smoothing by Moving Average

# %% [markdown]
# 이동평균선 plot

# %%
df2 = df

# %%
df2["close"].plot(figsize=(15, 8))
df2["close"].rolling(window=30).mean().plot() # 30일 이동평균선

# %%
df2["close_MA30"] = df2["close"].rolling(window=30).mean()
df2.head()
# Out:
#         Date       open       high        low      close      volume  \
# 0 2017-09-25  4201000.0  4333000.0  4175000.0  4322000.0  132.484755
# 1 2017-09-26  4317000.0  4418000.0  4311000.0  4321000.0   22.788340
# 2 2017-09-27  4322000.0  4677000.0  4318000.0  4657000.0   32.269662
# 3 2017-09-28  4657000.0  4772000.0  4519000.0  4586000.0   80.588243
# 4 2017-09-29  4586000.0  4709000.0  4476000.0  4657000.0   59.352373
#
#           value  vix_close  trends  close_MA30
# 0  5.602146e+08      10.21    12.0         NaN
# 1  9.950724e+07      10.17    12.0         NaN
# 2  1.448276e+08       9.87    12.0         NaN
# 3  3.721860e+08       9.55    12.0         NaN
# 4  2.724558e+08       9.51    12.0         NaN

# %%
df2["close_ma5"] = df2["close"].rolling(window=5).mean()
df2["close_ma10"] = df2["close"].rolling(window=10).mean()
df2["close_ma20"] = df2["close"].rolling(window=20).mean()
df2["close_ma60"] = df2["close"].rolling(window=60).mean()
#df2["close_diff_ma120"] = df2["close_diff"].rolling(window=120).mean()

# %%
df2["vix_close_ma5"] = df2["vix_close"].rolling(window=5).mean()
df2["vix_close_ma10"] = df2["vix_close"].rolling(window=10).mean()
df2["vix_close_ma20"] = df2["vix_close"].rolling(window=20).mean()
df2["vix_close_ma60"] = df2["vix_close"].rolling(window=60).mean()
#df2["vix_close_diff_ma120"] = df2["vix_close"].rolling(window=120).mean()

# %%
df = df2[["close_ma5", "close_ma10", "close_ma20", "close_ma60", 
          "vix_close_ma5", "vix_close_ma10", "vix_close_ma20", "vix_close_ma60",
          "trends", "close"]]
df.head(30)
# Out:
#     close_ma5  close_ma10  close_ma20  close_ma60  vix_close_ma5  \
# 0         NaN         NaN         NaN         NaN            NaN
# 1         NaN         NaN         NaN         NaN            NaN
# 2         NaN         NaN         NaN         NaN            NaN
# 3         NaN         NaN         NaN         NaN            NaN
# 4   4508600.0         NaN         NaN         NaN          9.862
# 5   4623200.0         NaN         NaN         NaN          9.722
# 6   4751400.0         NaN         NaN         NaN          9.590
# 7   4825000.0         NaN         NaN         NaN          9.506
# 8   4900600.0         NaN         NaN         NaN          9.498
# 9   4948200.0   4728400.0         NaN         NaN          9.522
# 10  4954400.0   4788800.0         NaN         NaN          9.458
# 11  4967400.0   4859400.0         NaN         NaN          9.486
# 12  4971800.0   4898400.0         NaN         NaN          9.526
# 13  5022400.0   4961500.0         NaN         NaN          9.554
# 14  5138800.0   5043500.0         NaN         NaN          9.694
# 15  5250800.0   5102600.0         NaN         NaN          9.872
# 16  5356800.0   5162100.0         NaN         NaN          9.912
# 17  5613800.0   5292800.0         NaN         NaN          9.964
# 18  5858000.0   5440200.0         NaN         NaN          9.956
# 19  6095400.0   5617100.0   5172750.0         NaN          9.812
# 20  6274400.0   5762600.0   5275700.0         NaN          9.718
# 21  6461200.0   5909000.0   5384200.0         NaN          9.730
# 22  6486200.0   6050000.0   5474200.0         NaN          9.810
# 23  6476800.0   6167400.0   5564450.0         NaN          9.902
# 24  6446200.0   6270800.0   5657150.0         NaN          9.990
# 25  6555600.0   6415000.0   5758800.0         NaN         10.062
# 26  6632200.0   6546700.0   5854400.0         NaN         10.074
# 27  6748600.0   6617400.0   5955100.0         NaN         10.006
# 28  6864600.0   6670700.0   6055450.0         NaN         10.206
# 29  6858200.0   6652200.0   6134650.0         NaN         10.428
#
#     vix_close_ma10  vix_close_ma20  vix_close_ma60  trends      close
# 0              NaN             NaN             NaN    12.0  4322000.0
# 1              NaN             NaN             NaN    12.0  4321000.0
# 2              NaN             NaN             NaN    12.0  4657000.0
# 3              NaN             NaN             NaN    12.0  4586000.0
# 4              NaN             NaN             NaN    12.0  4657000.0
# 5              NaN             NaN             NaN    12.0  4895000.0
# 6              NaN             NaN             NaN    12.0  4962000.0
# 7              NaN             NaN             NaN    12.0  5025000.0
# 8              NaN             NaN             NaN    12.0  4964000.0
# 9            9.692             NaN             NaN    12.0  4895000.0
# 10           9.590             NaN             NaN    12.0  4926000.0
# 11           9.538             NaN             NaN    12.0  5027000.0
# 12           9.516             NaN             NaN    12.0  5047000.0
# 13           9.526             NaN             NaN    18.0  5217000.0
# 14           9.608             NaN             NaN    18.0  5477000.0
# 15           9.665             NaN             NaN    18.0  5486000.0
# 16           9.699             NaN             NaN    18.0  5557000.0
# 17           9.745             NaN             NaN    18.0  6332000.0
# 18           9.755             NaN             NaN    18.0  6438000.0
# 19           9.753          9.7225             NaN    18.0  6664000.0
# 20           9.795          9.6925             NaN    19.0  6381000.0
# 21           9.821          9.6795             NaN    19.0  6491000.0
# 22           9.887          9.7015             NaN    19.0  6457000.0
# 23           9.929          9.7275             NaN    19.0  6391000.0
# 24           9.901          9.7545             NaN    19.0  6511000.0
# 25           9.890          9.7775             NaN    19.0  6928000.0
# 26           9.902          9.8005             NaN    19.0  6874000.0
# 27           9.908          9.8265             NaN    20.0  7039000.0
# 28          10.054          9.9045             NaN    20.0  6971000.0
# 29          10.209          9.9810             NaN    20.0  6479000.0

# %% [markdown]
# # 1691 - 60 = 1631

# %%
df = df.dropna()
df_drop = df
df.head()
# Out:
#     close_ma5  close_ma10  close_ma20    close_ma60  vix_close_ma5  \
# 59  8953200.0   8657600.0   8277800.0  6.798617e+06         10.314
# 60  9038200.0   8818000.0   8320250.0  6.879833e+06          9.962
# 61  9209000.0   8970900.0   8391550.0  6.972467e+06          9.766
# 62  9489000.0   9134300.0   8505750.0  7.067250e+06          9.754
# 63  9935000.0   9411600.0   8659300.0  7.179383e+06          9.752
#
#     vix_close_ma10  vix_close_ma20  vix_close_ma60  trends       close
# 59          11.091         10.7065       10.209167    27.0   8943000.0
# 60          10.899         10.7330       10.200167    27.0   9195000.0
# 61          10.553         10.7595       10.191833    27.0   9879000.0
# 62          10.344         10.7730       10.188500    61.0  10344000.0
# 63          10.188         10.7720       10.193833    61.0  11314000.0

# %%
len(df)
# Out:
# 1638

# %%
# df[["close_diff_ma5", "close_diff_ma10", "close_diff_ma20", "close_diff_ma60", "close_diff_ma120"]].plot.line()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os

# %matplotlib inline
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'NanumGothic'

# %%
# inverse transform
def restore(row):
  return row * (max(df_drop["close"]) - min(df_drop["close"])) + min(df_drop["close"])

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
# 스케일을 적용할 column을 정의합니다.
scale_cols = ["close_ma5", "close_ma10", "close_ma20", "close_ma60", 
              "vix_close_ma5", "vix_close_ma10", "vix_close_ma20", "vix_close_ma60",
              "trends", "close"]
# 스케일 후 columns
scaled = scaler.fit_transform(df[scale_cols])

# %%
df = pd.DataFrame(scaled, columns=scale_cols)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('close', 1), df['close'], test_size=0.2, random_state=0, shuffle=False)

# %% [markdown]
# # train set 80% -> 1631 * 0.8 = 1304.8 -> 1304 data

# %%
x_train.shape, y_train.shape
# Out:
# ((1310, 9), (1310,))

# %% [markdown]
# # test set 20% -> 1631 * 0.2 = 326.2 -> 327 data

# %%
x_test.shape, y_test.shape
# Out:
# ((328, 9), (328,))

# %%
x_train.tail()
# Out:
#       close_ma5  close_ma10  close_ma20  close_ma60  vix_close_ma5  \
# 1305   0.520824    0.537258    0.541669    0.713805       0.158901
# 1306   0.500057    0.528820    0.537659    0.708366       0.158106
# 1307   0.481475    0.523941    0.533551    0.702795       0.154773
# 1308   0.472219    0.516354    0.529163    0.697546       0.141381
# 1309   0.466989    0.507785    0.527202    0.692784       0.126919
#
#       vix_close_ma10  vix_close_ma20  vix_close_ma60    trends
# 1305        0.139399        0.137043        0.206037  0.322581
# 1306        0.143149        0.137034        0.205694  0.322581
# 1307        0.144840        0.136298        0.205413  0.322581
# 1308        0.145962        0.134755        0.204990  0.322581
# 1309        0.145259        0.134351        0.204421  0.322581

# %%
y_train.tail()
# Out:
# 1305    0.491399
# 1306    0.434202
# 1307    0.439229
# 1308    0.455852
# 1309    0.468978
# Name: close, dtype: float64

# %%
len(y_train)
# Out:
# 1310

# %%
x_test.tail()
# Out:
#       close_ma5  close_ma10  close_ma20  close_ma60  vix_close_ma5  \
# 1633   0.476508    0.520303    0.584394    0.671239       0.333364
# 1634   0.476140    0.511282    0.577690    0.668954       0.320767
# 1635   0.473423    0.500877    0.571115    0.666347       0.305204
# 1636   0.473465    0.491178    0.563730    0.663573       0.287868
# 1637   0.471573    0.482854    0.555422    0.660514       0.280835
#
#       vix_close_ma10  vix_close_ma20  vix_close_ma60    trends
# 1633        0.362443        0.381546        0.379253  0.365591
# 1634        0.358542        0.383206        0.380175  0.204301
# 1635        0.353988        0.377776        0.380928  0.204301
# 1636        0.347140        0.372839        0.381863  0.204301
# 1637        0.341080        0.369769        0.382993  0.204301

# %%
y_test.tail()
# Out:
# 1633    0.467294
# 1634    0.479366
# 1635    0.458153
# 1636    0.458192
# 1637    0.449077
# Name: close, dtype: float64

# %%
len(y_test)
# Out:
# 328

# %%
df2 = df_org
df2.tail()
# Out:
#                          index        open        high         low  \
# 1692 2022-05-14 09:00:00+00:00  39270000.0  40243000.0  38400000.0
# 1693 2022-05-15 09:00:00+00:00  39967000.0  41000000.0  39270000.0
# 1694 2022-05-16 09:00:00+00:00  40902000.0  40940000.0  38620000.0
# 1695 2022-05-17 09:00:00+00:00  39260000.0  39900000.0  38416000.0
# 1696 2022-05-18 09:00:00+00:00  39260000.0  39464000.0  38440000.0
#
#            close       volume         value
# 1692  39967000.0  5512.195620  2.170088e+11
# 1693  40906000.0  4277.655034  1.706726e+11
# 1694  39256000.0  5678.833853  2.243704e+11
# 1695  39259000.0  5356.753182  2.105359e+11
# 1696  38550000.0  2196.484708  8.528940e+10

# %% [markdown]
# TensorFlow Dataset을 활용한 시퀀스 데이터셋 구성

# %%
import tensorflow as tf

# %%
def windowed_dataset(series, window_size, batch_size, shuffle):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    if shuffle:
        ds = ds.shuffle(1000)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    return ds.batch(batch_size).prefetch(1)

# %%
WINDOW_SIZE=20
BATCH_SIZE=32

# %%
# trian_data는 학습용 데이터셋, test_data는 검증용 데이터셋 입니다.
train_data = windowed_dataset(y_train, WINDOW_SIZE, BATCH_SIZE, True)
test_data = windowed_dataset(y_test, WINDOW_SIZE, BATCH_SIZE, False)

# %%
# 아래의 코드로 데이터셋의 구성을 확인해 볼 수 있습니다.
# X: (batch_size, window_size, feature)
# Y: (batch_size, feature)
for data in train_data.take(1):
    print(f'데이터셋(X) 구성(batch_size, window_size, feature갯수): {data[0].shape}')
    print(f'데이터셋(Y) 구성(batch_size, window_size, feature갯수): {data[1].shape}')
# Out:
# 데이터셋(X) 구성(batch_size, window_size, feature갯수): (32, 20, 1)
# 데이터셋(Y) 구성(batch_size, window_size, feature갯수): (32, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Lambda
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


model = Sequential([
    # 1차원 feature map 생성
    Conv1D(filters=32, kernel_size=5,
           padding="causal",
           activation="relu",
           input_shape=[WINDOW_SIZE, 1]),
    # LSTM
    LSTM(16, activation='tanh'),
    Dense(16, activation="relu"),
    Dense(1),
])

# %%
# Sequence 학습에 비교적 좋은 퍼포먼스를 내는 Huber()를 사용합니다.
loss = Huber()
optimizer = Adam(0.0005)
model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

# %%
# earlystopping은 10번 epoch통안 val_loss 개선이 없다면 학습을 멈춥니다.
earlystopping = EarlyStopping(monitor='val_loss', patience=10)
# val_loss 기준 체크포인터도 생성합니다.
filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename, 
                             save_weights_only=True, 
                             save_best_only=True, 
                             monitor='val_loss', 
                             verbose=1)

# %%
history = model.fit(train_data, 
                    validation_data=(test_data), 
                    epochs=50, 
                    callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/50
#      40/Unknown - 3s 11ms/step - loss: 0.0172 - mse: 0.0344
# Epoch 1: val_loss improved from inf to 0.02581, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 4s 36ms/step - loss: 0.0171 - mse: 0.0341 - val_loss: 0.0258 - val_mse: 0.0516
# Epoch 2/50
# 37/41 [==========================>...] - ETA: 0s - loss: 0.0019 - mse: 0.0037
# Epoch 2: val_loss improved from 0.02581 to 0.00147, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 17ms/step - loss: 0.0018 - mse: 0.0036 - val_loss: 0.0015 - val_mse: 0.0029
# Epoch 3/50
# 38/41 [==========================>...] - ETA: 0s - loss: 4.8211e-04 - mse: 9.6422e-04
# Epoch 3: val_loss improved from 0.00147 to 0.00125, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 14ms/step - loss: 4.7408e-04 - mse: 9.4816e-04 - val_loss: 0.0013 - val_mse: 0.0025
# Epoch 4/50
# 39/41 [===========================>..] - ETA: 0s - loss: 4.5249e-04 - mse: 9.0499e-04
# Epoch 4: val_loss improved from 0.00125 to 0.00112, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 15ms/step - loss: 4.5057e-04 - mse: 9.0114e-04 - val_loss: 0.0011 - val_mse: 0.0022
# Epoch 5/50
# 38/41 [==========================>...] - ETA: 0s - loss: 4.0973e-04 - mse: 8.1946e-04
# Epoch 5: val_loss improved from 0.00112 to 0.00108, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 15ms/step - loss: 4.1697e-04 - mse: 8.3394e-04 - val_loss: 0.0011 - val_mse: 0.0022
# Epoch 6/50
# 41/41 [==============================] - ETA: 0s - loss: 3.9966e-04 - mse: 7.9933e-04
# Epoch 6: val_loss did not improve from 0.00108
# 41/41 [==============================] - 1s 15ms/step - loss: 3.9966e-04 - mse: 7.9933e-04 - val_loss: 0.0011 - val_mse: 0.0022
# Epoch 7/50
# 36/41 [=========================>....] - ETA: 0s - loss: 3.8913e-04 - mse: 7.7826e-04
# Epoch 7: val_loss improved from 0.00108 to 0.00096, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 14ms/step - loss: 3.9053e-04 - mse: 7.8105e-04 - val_loss: 9.5758e-04 - val_mse: 0.0019
# Epoch 8/50
# 39/41 [===========================>..] - ETA: 0s - loss: 3.7557e-04 - mse: 7.5114e-04
# Epoch 8: val_loss did not improve from 0.00096
# 41/41 [==============================] - 1s 14ms/step - loss: 3.7500e-04 - mse: 7.5001e-04 - val_loss: 0.0011 - val_mse: 0.0023
# Epoch 9/50
# 39/41 [===========================>..] - ETA: 0s - loss: 3.5997e-04 - mse: 7.1995e-04
# Epoch 9: val_loss improved from 0.00096 to 0.00090, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 14ms/step - loss: 3.5594e-04 - mse: 7.1188e-04 - val_loss: 8.9508e-04 - val_mse: 0.0018
# Epoch 10/50
# 36/41 [=========================>....] - ETA: 0s - loss: 3.5407e-04 - mse: 7.0814e-04
# Epoch 10: val_loss did not improve from 0.00090
# 41/41 [==============================] - 1s 13ms/step - loss: 3.4341e-04 - mse: 6.8682e-04 - val_loss: 9.0025e-04 - val_mse: 0.0018
# Epoch 11/50
# 39/41 [===========================>..] - ETA: 0s - loss: 3.2904e-04 - mse: 6.5809e-04
# Epoch 11: val_loss did not improve from 0.00090
# 41/41 [==============================] - 1s 14ms/step - loss: 3.2141e-04 - mse: 6.4283e-04 - val_loss: 9.0431e-04 - val_mse: 0.0018
# Epoch 12/50
# 39/41 [===========================>..] - ETA: 0s - loss: 3.4077e-04 - mse: 6.8154e-04
# Epoch 12: val_loss improved from 0.00090 to 0.00078, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 15ms/step - loss: 3.3715e-04 - mse: 6.7431e-04 - val_loss: 7.8299e-04 - val_mse: 0.0016
# Epoch 13/50
# 38/41 [==========================>...] - ETA: 0s - loss: 3.1414e-04 - mse: 6.2828e-04
# Epoch 13: val_loss improved from 0.00078 to 0.00075, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 17ms/step - loss: 3.1164e-04 - mse: 6.2328e-04 - val_loss: 7.4639e-04 - val_mse: 0.0015
# Epoch 14/50
# 39/41 [===========================>..] - ETA: 0s - loss: 3.2301e-04 - mse: 6.4601e-04
# Epoch 14: val_loss improved from 0.00075 to 0.00073, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 15ms/step - loss: 3.1684e-04 - mse: 6.3368e-04 - val_loss: 7.2592e-04 - val_mse: 0.0015
# Epoch 15/50
# 38/41 [==========================>...] - ETA: 0s - loss: 2.6368e-04 - mse: 5.2736e-04
# Epoch 15: val_loss did not improve from 0.00073
# 41/41 [==============================] - 1s 14ms/step - loss: 2.8065e-04 - mse: 5.6131e-04 - val_loss: 7.7854e-04 - val_mse: 0.0016
# Epoch 16/50
# 39/41 [===========================>..] - ETA: 0s - loss: 2.8670e-04 - mse: 5.7340e-04
# Epoch 16: val_loss improved from 0.00073 to 0.00071, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 14ms/step - loss: 2.8634e-04 - mse: 5.7268e-04 - val_loss: 7.0549e-04 - val_mse: 0.0014
# Epoch 17/50
# 39/41 [===========================>..] - ETA: 0s - loss: 2.8689e-04 - mse: 5.7378e-04
# Epoch 17: val_loss improved from 0.00071 to 0.00064, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 17ms/step - loss: 2.8565e-04 - mse: 5.7130e-04 - val_loss: 6.3952e-04 - val_mse: 0.0013
# Epoch 18/50
# 37/41 [==========================>...] - ETA: 0s - loss: 2.6631e-04 - mse: 5.3262e-04
# Epoch 18: val_loss did not improve from 0.00064
# 41/41 [==============================] - 1s 15ms/step - loss: 2.6117e-04 - mse: 5.2235e-04 - val_loss: 6.5214e-04 - val_mse: 0.0013
# Epoch 19/50
# 38/41 [==========================>...] - ETA: 0s - loss: 2.5328e-04 - mse: 5.0656e-04
# Epoch 19: val_loss did not improve from 0.00064
# 41/41 [==============================] - 1s 15ms/step - loss: 2.5623e-04 - mse: 5.1246e-04 - val_loss: 8.8931e-04 - val_mse: 0.0018
# Epoch 20/50
# 38/41 [==========================>...] - ETA: 0s - loss: 2.3393e-04 - mse: 4.6786e-04
# Epoch 20: val_loss improved from 0.00064 to 0.00059, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 15ms/step - loss: 2.3573e-04 - mse: 4.7146e-04 - val_loss: 5.8846e-04 - val_mse: 0.0012
# Epoch 21/50
# 41/41 [==============================] - ETA: 0s - loss: 2.3669e-04 - mse: 4.7337e-04
# Epoch 21: val_loss did not improve from 0.00059
# 41/41 [==============================] - 1s 24ms/step - loss: 2.3669e-04 - mse: 4.7337e-04 - val_loss: 6.8417e-04 - val_mse: 0.0014
# Epoch 22/50
# 37/41 [==========================>...] - ETA: 0s - loss: 2.4703e-04 - mse: 4.9405e-04
# Epoch 22: val_loss improved from 0.00059 to 0.00053, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 17ms/step - loss: 2.3673e-04 - mse: 4.7346e-04 - val_loss: 5.3242e-04 - val_mse: 0.0011
# Epoch 23/50
# 36/41 [=========================>....] - ETA: 0s - loss: 2.1783e-04 - mse: 4.3566e-04
# Epoch 23: val_loss did not improve from 0.00053
# 41/41 [==============================] - 1s 15ms/step - loss: 2.1802e-04 - mse: 4.3605e-04 - val_loss: 5.4300e-04 - val_mse: 0.0011
# Epoch 24/50
# 40/41 [============================>.] - ETA: 0s - loss: 2.0674e-04 - mse: 4.1347e-04
# Epoch 24: val_loss improved from 0.00053 to 0.00051, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 15ms/step - loss: 2.0670e-04 - mse: 4.1341e-04 - val_loss: 5.1008e-04 - val_mse: 0.0010
# Epoch 25/50
# 39/41 [===========================>..] - ETA: 0s - loss: 1.9925e-04 - mse: 3.9849e-04
# Epoch 25: val_loss improved from 0.00051 to 0.00049, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 15ms/step - loss: 1.9720e-04 - mse: 3.9439e-04 - val_loss: 4.8689e-04 - val_mse: 9.7378e-04
# Epoch 26/50
# 37/41 [==========================>...] - ETA: 0s - loss: 1.9658e-04 - mse: 3.9315e-04
# Epoch 26: val_loss improved from 0.00049 to 0.00047, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 18ms/step - loss: 1.8867e-04 - mse: 3.7735e-04 - val_loss: 4.6853e-04 - val_mse: 9.3706e-04
# Epoch 27/50
# 40/41 [============================>.] - ETA: 0s - loss: 1.9224e-04 - mse: 3.8447e-04
# Epoch 27: val_loss improved from 0.00047 to 0.00047, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 16ms/step - loss: 1.9377e-04 - mse: 3.8753e-04 - val_loss: 4.6557e-04 - val_mse: 9.3115e-04
# Epoch 28/50
# 37/41 [==========================>...] - ETA: 0s - loss: 2.0514e-04 - mse: 4.1029e-04
# Epoch 28: val_loss improved from 0.00047 to 0.00044, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 19ms/step - loss: 2.0291e-04 - mse: 4.0581e-04 - val_loss: 4.3769e-04 - val_mse: 8.7538e-04
# Epoch 29/50
# 39/41 [===========================>..] - ETA: 0s - loss: 1.6640e-04 - mse: 3.3280e-04
# Epoch 29: val_loss improved from 0.00044 to 0.00042, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 19ms/step - loss: 1.7436e-04 - mse: 3.4872e-04 - val_loss: 4.2474e-04 - val_mse: 8.4947e-04
# Epoch 30/50
# 40/41 [============================>.] - ETA: 0s - loss: 2.1277e-04 - mse: 4.2555e-04
# Epoch 30: val_loss did not improve from 0.00042
# 41/41 [==============================] - 1s 16ms/step - loss: 2.1307e-04 - mse: 4.2614e-04 - val_loss: 7.3749e-04 - val_mse: 0.0015
# Epoch 31/50
# 39/41 [===========================>..] - ETA: 0s - loss: 1.9049e-04 - mse: 3.8098e-04
# Epoch 31: val_loss improved from 0.00042 to 0.00041, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 17ms/step - loss: 2.0659e-04 - mse: 4.1319e-04 - val_loss: 4.0922e-04 - val_mse: 8.1844e-04
# Epoch 32/50
# 38/41 [==========================>...] - ETA: 0s - loss: 1.9611e-04 - mse: 3.9222e-04
# Epoch 32: val_loss did not improve from 0.00041
# 41/41 [==============================] - 1s 17ms/step - loss: 1.9681e-04 - mse: 3.9362e-04 - val_loss: 4.8993e-04 - val_mse: 9.7985e-04
# Epoch 33/50
# 39/41 [===========================>..] - ETA: 0s - loss: 1.8184e-04 - mse: 3.6368e-04
# Epoch 33: val_loss improved from 0.00041 to 0.00041, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 15ms/step - loss: 1.7681e-04 - mse: 3.5363e-04 - val_loss: 4.0811e-04 - val_mse: 8.1621e-04
# Epoch 34/50
# 39/41 [===========================>..] - ETA: 0s - loss: 1.5856e-04 - mse: 3.1712e-04
# Epoch 34: val_loss improved from 0.00041 to 0.00038, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 15ms/step - loss: 1.5814e-04 - mse: 3.1628e-04 - val_loss: 3.7532e-04 - val_mse: 7.5065e-04
# Epoch 35/50
# 37/41 [==========================>...] - ETA: 0s - loss: 1.5006e-04 - mse: 3.0011e-04
# Epoch 35: val_loss did not improve from 0.00038
# 41/41 [==============================] - 1s 13ms/step - loss: 1.5227e-04 - mse: 3.0454e-04 - val_loss: 3.9583e-04 - val_mse: 7.9165e-04
# Epoch 36/50
# 38/41 [==========================>...] - ETA: 0s - loss: 1.6135e-04 - mse: 3.2271e-04
# Epoch 36: val_loss improved from 0.00038 to 0.00037, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 13ms/step - loss: 1.6050e-04 - mse: 3.2100e-04 - val_loss: 3.7385e-04 - val_mse: 7.4769e-04
# Epoch 37/50
# 40/41 [============================>.] - ETA: 0s - loss: 1.5631e-04 - mse: 3.1262e-04
# Epoch 37: val_loss did not improve from 0.00037
# 41/41 [==============================] - 1s 14ms/step - loss: 1.5644e-04 - mse: 3.1288e-04 - val_loss: 3.8233e-04 - val_mse: 7.6465e-04
# Epoch 38/50
# 40/41 [============================>.] - ETA: 0s - loss: 1.5006e-04 - mse: 3.0012e-04
# Epoch 38: val_loss did not improve from 0.00037
# 41/41 [==============================] - 1s 14ms/step - loss: 1.5014e-04 - mse: 3.0029e-04 - val_loss: 4.8064e-04 - val_mse: 9.6128e-04
# Epoch 39/50
# 37/41 [==========================>...] - ETA: 0s - loss: 1.4203e-04 - mse: 2.8406e-04
# Epoch 39: val_loss did not improve from 0.00037
# 41/41 [==============================] - 1s 13ms/step - loss: 1.4456e-04 - mse: 2.8912e-04 - val_loss: 4.4413e-04 - val_mse: 8.8825e-04
# Epoch 40/50
# 37/41 [==========================>...] - ETA: 0s - loss: 1.3930e-04 - mse: 2.7860e-04
# Epoch 40: val_loss improved from 0.00037 to 0.00036, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 17ms/step - loss: 1.4052e-04 - mse: 2.8104e-04 - val_loss: 3.6012e-04 - val_mse: 7.2024e-04
# Epoch 41/50
# 39/41 [===========================>..] - ETA: 0s - loss: 1.4889e-04 - mse: 2.9778e-04
# Epoch 41: val_loss did not improve from 0.00036
# 41/41 [==============================] - 1s 13ms/step - loss: 1.5081e-04 - mse: 3.0162e-04 - val_loss: 3.6421e-04 - val_mse: 7.2842e-04
# Epoch 42/50
# 37/41 [==========================>...] - ETA: 0s - loss: 1.4369e-04 - mse: 2.8738e-04
# Epoch 42: val_loss did not improve from 0.00036
# 41/41 [==============================] - 1s 13ms/step - loss: 1.4215e-04 - mse: 2.8431e-04 - val_loss: 5.3652e-04 - val_mse: 0.0011
# Epoch 43/50
# 41/41 [==============================] - ETA: 0s - loss: 1.4039e-04 - mse: 2.8078e-04
# Epoch 43: val_loss did not improve from 0.00036
# 41/41 [==============================] - 1s 14ms/step - loss: 1.4039e-04 - mse: 2.8078e-04 - val_loss: 3.6119e-04 - val_mse: 7.2238e-04
# Epoch 44/50
# 41/41 [==============================] - ETA: 0s - loss: 1.3836e-04 - mse: 2.7671e-04
# Epoch 44: val_loss improved from 0.00036 to 0.00034, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 15ms/step - loss: 1.3836e-04 - mse: 2.7671e-04 - val_loss: 3.4071e-04 - val_mse: 6.8143e-04
# Epoch 45/50
# 39/41 [===========================>..] - ETA: 0s - loss: 1.3723e-04 - mse: 2.7445e-04
# Epoch 45: val_loss did not improve from 0.00034
# 41/41 [==============================] - 1s 17ms/step - loss: 1.3758e-04 - mse: 2.7517e-04 - val_loss: 3.7959e-04 - val_mse: 7.5917e-04
# Epoch 46/50
# 39/41 [===========================>..] - ETA: 0s - loss: 1.7856e-04 - mse: 3.5711e-04
# Epoch 46: val_loss did not improve from 0.00034
# 41/41 [==============================] - 1s 16ms/step - loss: 1.8277e-04 - mse: 3.6554e-04 - val_loss: 3.4611e-04 - val_mse: 6.9222e-04
# Epoch 47/50
# 38/41 [==========================>...] - ETA: 0s - loss: 1.9486e-04 - mse: 3.8972e-04
# Epoch 47: val_loss improved from 0.00034 to 0.00034, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 15ms/step - loss: 1.9514e-04 - mse: 3.9027e-04 - val_loss: 3.3851e-04 - val_mse: 6.7702e-04
# Epoch 48/50
# 36/41 [=========================>....] - ETA: 0s - loss: 1.2646e-04 - mse: 2.5292e-04
# Epoch 48: val_loss improved from 0.00034 to 0.00033, saving model to tmp/ckeckpointer.ckpt
# 41/41 [==============================] - 1s 13ms/step - loss: 1.3086e-04 - mse: 2.6171e-04 - val_loss: 3.2689e-04 - val_mse: 6.5377e-04
# Epoch 49/50
# 41/41 [==============================] - ETA: 0s - loss: 1.2986e-04 - mse: 2.5973e-04
# Epoch 49: val_loss did not improve from 0.00033
# 41/41 [==============================] - 1s 21ms/step - loss: 1.2986e-04 - mse: 2.5973e-04 - val_loss: 3.3773e-04 - val_mse: 6.7546e-04
# Epoch 50/50
# 39/41 [===========================>..] - ETA: 0s - loss: 1.2444e-04 - mse: 2.4889e-04
# Epoch 50: val_loss did not improve from 0.00033
# 41/41 [==============================] - 1s 16ms/step - loss: 1.2695e-04 - mse: 2.5390e-04 - val_loss: 4.4437e-04 - val_mse: 8.8874e-04

# %%
model.load_weights(filename)

# %%
pred = model.predict(test_data)

# %% [markdown]
# pred: test set - 20(window size)  = 314 - 20 = 294

# %%
pred.shape
# Out:
# (308, 1)

# %% [markdown]
# 예측 데이터 시각화

# %%
plt.figure(figsize=(12, 9))
plt.plot(restore(np.asarray(y_test)[20:]), label='actual')
plt.plot(restore(pred), label='prediction')
plt.legend()
plt.show()
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
df_actu = df_org[-len(pred):]
df_actu.tail()
# Out:
#                          index        open        high         low  \
# 1692 2022-05-14 09:00:00+00:00  39270000.0  40243000.0  38400000.0
# 1693 2022-05-15 09:00:00+00:00  39967000.0  41000000.0  39270000.0
# 1694 2022-05-16 09:00:00+00:00  40902000.0  40940000.0  38620000.0
# 1695 2022-05-17 09:00:00+00:00  39260000.0  39900000.0  38416000.0
# 1696 2022-05-18 09:00:00+00:00  39260000.0  39464000.0  38440000.0
#
#            close       volume         value
# 1692  39967000.0  5512.195620  2.170088e+11
# 1693  40906000.0  4277.655034  1.706726e+11
# 1694  39256000.0  5678.833853  2.243704e+11
# 1695  39259000.0  5356.753182  2.105359e+11
# 1696  38550000.0  2196.484708  8.528940e+10

# %%
df_actu["pred"] = restore(pred)
df_actu = df_actu[["close", "pred"]]
df_actu.tail()
# Out:
#            close        pred
# 1692  39967000.0  38612328.0
# 1693  40906000.0  38673672.0
# 1694  39256000.0  39327148.0
# 1695  39259000.0  39395664.0
# 1696  38550000.0  39368736.0
